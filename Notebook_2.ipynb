# %%
import http.client

conn = http.client.HTTPSConnection("yahoo-finance166.p.rapidapi.com")

headers = {
    'x-rapidapi-key': "129c3cc8cemsh9f6fe87d699110fp12c88fjsna3a0a0f62e2e",
    'x-rapidapi-host': "yahoo-finance166.p.rapidapi.com"
}

conn.request("GET", "/api/news/list-by-symbol?s=AAPL%2CGOOGL%2CTSLA&region=US&snippetCount=500", headers=headers)

res = conn.getresponse()
data = res.read()

data.decode("utf-8")
# Out:
# '{"data":{"main":{"stream":[{"id":"041dc48a-4c9c-4c18-a9e4-c79190a65527","content":{"id":"041dc48a-4c9c-4c18-a9e4-c79190a65527","contentType":"STORY","title":"Nvidia to win the race to $4 trillion market cap, experts say","isHosted":true,"clickThroughUrl":{"url":"https://finance.yahoo.com/news/nvidia-to-win-the-race-to-4-trillion-market-cap-experts-say-131512935.html"},"previewUrl":null,"pubDate":"2024-10-19T13:15:12Z","hasVideo":false,"thumbnail":{"resolutions":[{"url":"https://s.yimg.com/uu/api/res/1.2/gyYfK9eyHk_sK960qTRw2A--~B/aD0zMzMzO3c9NTAwMDthcHBpZD15dGFjaHlvbg--/https://s.yimg.com/os/creatr-uploaded-images/2024-08/9da02850-5fd0-11ef-a5bf-b01c94a94913","width":5000,"height":3333,"tag":"original"},{"url":"https://s.yimg.com/uu/api/res/1.2/AC0hk.KaAwHPf4E8Pv9Hcw--~B/Zmk9c3RyaW07aD0xNDA7dz0xNDA7YXBwaWQ9eXRhY2h5b24-/https://s.yimg.com/os/creatr-uploaded-images/2024-08/9da02850-5fd0-11ef-a5bf-b01c94a94913","width":140,"height":140,"tag":"140x140"},{"url":"https://s.yimg.com/uu/api
# ...

# %% [markdown]
# LIST OF ALL NEWS HEADLINES - YAHOO FINANCE

# %%
import http.client
import json

# Make the HTTP request
conn = http.client.HTTPSConnection("yahoo-finance166.p.rapidapi.com")

headers = {
    'x-rapidapi-key': "129c3cc8cemsh9f6fe87d699110fp12c88fjsna3a0a0f62e2e",
    'x-rapidapi-host': "yahoo-finance166.p.rapidapi.com"
}

conn.request("GET", "/api/news/list-by-symbol?s=AAPL%2CGOOGL%2CTSLA&region=US&snippetCount=500", headers=headers)

res = conn.getresponse()
data = res.read()

decoded_data = data.decode("utf-8")
json_data = json.loads(decoded_data)

titles = [item['content']['title'] for item in json_data['data']['main']['stream']]
count = 0
for title in titles:
    count = count+1
    print(title)
print (count)
conn.close()
# Out:
# Nvidia to win the race to $4 trillion market cap, experts say
# Alphabet Inc. (GOOGL): Among the Most Owned Stocks by Hedge Funds Right Now
# Apple Inc. (AAPL): Among the Most Owned Stocks by Hedge Funds Right Now
# Nuclear energy stocks hit record highs on surging demand from AI
# Tesla, Amazon — even Boeing — will move markets this week
# 2 Dividend Stocks to Double Up On Right Now
# Here's Why Uranium Energy Corp Stock Soared This Week
# Tesla Earnings Due Amid Model Y Refresh Buzz; BYD Reclaims Buy Zone
# This Hot Tech Stock Just Knocked Tesla Out Of The S&P 500 Magnificent Seven. Should You Be Buying?
# Goldman Sachs: Tesla, Inc. (NASDAQ:TSLA) Is A Stock With High Consensus ROE
# Should You Buy Tesla Stock Before Oct. 23? Here's What History Suggests
# Elon Musk Spent His Teen Years Working Odd Jobs In Canada. For $18 An Hour, He'd Clean The Boiler Room With 'No Escape' In A Lumber Mill
# 3 Reasons Rivian Is the Smartest Electric Vehicle (EV) Stock to Buy Right Now
# ...

# %%
import http.client

conn = http.client.HTTPSConnection("yahoo-finance166.p.rapidapi.com")

headers = {
    'x-rapidapi-key': "129c3cc8cemsh9f6fe87d699110fp12c88fjsna3a0a0f62e2e",
    'x-rapidapi-host': "yahoo-finance166.p.rapidapi.com"
}

conn.request("GET", "/api/news/details?uuid=27f132cd-ff15-4be3-8db2-02b6fc0f3c6c&region=US", headers=headers)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))

# %%
import http.client

conn = http.client.HTTPSConnection("yahoo-finance166.p.rapidapi.com")

headers = {
    'x-rapidapi-key': "129c3cc8cemsh9f6fe87d699110fp12c88fjsna3a0a0f62e2e",
    'x-rapidapi-host': "yahoo-finance166.p.rapidapi.com"
}

conn.request("GET", "/api/news/list-by-symbol?s=AAPL%2CGOOGL%2CTSLA&region=US&snippetCount=500", headers=headers)

res = conn.getresponse()
data = res.read()

decoded_data = data.decode("utf-8")
json_data = json.loads(decoded_data)

titles = [item['content']['title'] for item in json_data['data']['main']['stream']]
count = 0
for title in titles:
    count = count+1
    print(title)
print (count)
conn.close()

data.decode("utf-8")
# Out:
# '{"data":{"contents":[{"contentType":"STORY","id":"27f132cd-ff15-4be3-8db2-02b6fc0f3c6c","type":"CONTENT","content":{"id":"27f132cd-ff15-4be3-8db2-02b6fc0f3c6c","hideAdTypes":[],"isHosted":true,"contentType":"STORY","canonicalUrl":{"url":"https://finance.yahoo.com/news/floridas-condo-market-looks-shaky-could-the-bottom-fall-out-133009961.html"},"clickThroughUrl":{"url":"https://finance.yahoo.com/news/floridas-condo-market-looks-shaky-could-the-bottom-fall-out-133009961.html"},"ampUrl":"","title":"Florida\'s condo market looks shaky. Could the bottom fall out?","structuredSummary":{"summaries":[{"type":"text","value":"\\"FLORIDA CONDO MARKET REMAINS IN CORRECTION MODE,\\" Lance Lambert, co-founder of the ResiClub newsletter, posted at the end of last month, noting that condo prices were falling year over year in 18 metros in the state."},{"type":"text","value":"Another post last month from Nick Gerli, CEO of Reventure Consulting, a real estate analysis firm, showed that the estimated 
# ...

# %%
import http.client
import json  # Import the json module for parsing JSON data

# Set up the connection to the API
conn = http.client.HTTPSConnection("yahoo-finance166.p.rapidapi.com")

# Define headers including the API key
headers = {
    'x-rapidapi-key': "129c3cc8cemsh9f6fe87d699110fp12c88fjsna3a0a0f62e2e",
    'x-rapidapi-host': "yahoo-finance166.p.rapidapi.com"
}

# Send the GET request
conn.request("GET", "/api/news/details?uuid=27f132cd-ff15-4be3-8db2-02b6fc0f3c6c&region=US", headers=headers)

# Get the response
res = conn.getresponse()
data = res.read()

# Decode the data and load it as JSON
news_data = json.loads(data.decode("utf-8"))

# Check if the data contains the 'data' and 'contents' keys
if "data" in news_data and "contents" in news_data["data"]:
    contents = news_data["data"]["contents"]  # Get the list of contents
    num_entries = len(contents)  # Count the number of entries
    print(f"Number of entries: {num_entries}")
else:
    print("No contents found.")
# Out:
# Number of entries: 1

# %%
import requests

url = "https://yahoo-finance166.p.rapidapi.com/api/news/list-by-symbol"

querystring = {"s":"AAPL,GOOGL,TSLA","region":"US","snippetCount":"500"}

headers = {
	"x-rapidapi-key": "129c3cc8cemsh9f6fe87d699110fp12c88fjsna3a0a0f62e2e",
	"x-rapidapi-host": "yahoo-finance166.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

response.json()
# Out:
# {'data': {'main': {'stream': [{'id': '041dc48a-4c9c-4c18-a9e4-c79190a65527',
#      'content': {'id': '041dc48a-4c9c-4c18-a9e4-c79190a65527',
#       'contentType': 'STORY',
#       'title': 'Nvidia to win the race to $4 trillion market cap, experts say',
#       'isHosted': True,
#       'clickThroughUrl': {'url': 'https://finance.yahoo.com/news/nvidia-to-win-the-race-to-4-trillion-market-cap-experts-say-131512935.html'},
#       'previewUrl': None,
#       'pubDate': '2024-10-19T13:15:12Z',
#       'hasVideo': False,
#       'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/gyYfK9eyHk_sK960qTRw2A--~B/aD0zMzMzO3c9NTAwMDthcHBpZD15dGFjaHlvbg--/https://s.yimg.com/os/creatr-uploaded-images/2024-08/9da02850-5fd0-11ef-a5bf-b01c94a94913',
#          'width': 5000,
#          'height': 3333,
#          'tag': 'original'},
# ...

# %%
import requests
import pandas as pd  # Import pandas for creating a table

# Define the URL and parameters
url = "https://yahoo-finance166.p.rapidapi.com/api/news/list-by-symbol"
querystring = {"s": "AAPL,GOOGL,TSLA", "region": "US", "snippetCount": "500"}

# Define headers
headers = {
    "x-rapidapi-key": "129c3cc8cemsh9f6fe87d699110fp12c88fjsna3a0a0f62e2e",
    "x-rapidapi-host": "yahoo-finance166.p.rapidapi.com"
}

# Send GET request
response = requests.get(url, headers=headers, params=querystring)

# Load the JSON response
data = response.json()

# Extract relevant information
articles = []
if "data" in data and "main" in data["data"]:
    stream = data["data"]["main"]["stream"]
    for item in stream:
        article_content = item["content"]
        title = article_content.get("title", "No title available")
        pub_date = article_content.get("pubDate", "No date available")

        articles.append({"Headline": title, "Date": pub_date})

# Create a DataFrame from the articles list
df = pd.DataFrame(articles)

# Display the DataFrame
print(df)
# Out:
#                                               Headline                  Date
# 0    Nvidia to win the race to $4 trillion market c...  2024-10-19T13:15:12Z
# 1                     Lucid Stock: Buy, Sell, or Hold?  2024-10-20T10:00:00Z
# 2                         Is Alphabet Stock a Buy Now?  2024-10-20T09:32:00Z
# 3    Meet the Unstoppable Growth Stock That Could J...  2024-10-20T09:05:00Z
# 4    Tesla Stock vs. Alphabet Stock: Wall Street Sa...  2024-10-20T08:45:00Z
# ..                                                 ...                   ...
# 195  Apple's iPad Mini gets AI upgrade thanks to A1...  2024-10-16T17:00:00Z
# 196  Amazon signs nuclear power deals, following Go...  2024-10-16T16:07:05Z
# 197  Tesla Stock Investors Will Likely Be More Dema...  2024-10-16T16:00:00Z
# 198  Tesla moves $765 million in Bitcoin to unknown...  2024-10-16T15:43:58Z
# 199              2 Millionaire-Maker Technology Stocks  2024-10-16T15:23:00Z
#
# [200 rows x 2 columns]

# %%
def fetch_article_text(url):
    response = requests.get(url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        paragraphs = soup.find_all('p')
        article_text = ' '.join([para.get_text() for para in paragraphs])
        return article_text
    else:
        print(f"Failed to retrieve article: {response.status_code}")
        return None

def summarize_text(text):
    summarizer = pipeline("summarization")
    summary = summarizer(text, max_length=130, min_length=30, do_sample=False)
    return summary[0]['summary_text']

def processing(url):
  article_text = fetch_article_text(url)
  if article_text:
      summary = summarize_text(article_text)
      print("Article Summary:")
      print(summary)

# %% [markdown]
# **INTEGRATING URL GENERATION WITH SUMMARISATION**

# %%
import requests
import pandas as pd
import requests
from bs4 import BeautifulSoup
from transformers import pipeline


url = "https://yahoo-finance166.p.rapidapi.com/api/news/list-by-symbol"
querystring = {"s": "AAPL,GOOGL,TSLA", "region": "US", "snippetCount": "500"}

headers = {
    "x-rapidapi-key": "129c3cc8cemsh9f6fe87d699110fp12c88fjsna3a0a0f62e2e",
    "x-rapidapi-host": "yahoo-finance166.p.rapidapi.com"
}

# Function to process the URL (you can modify this as needed)
def process_url(url):
    print(f"Processing URL: {url}")

    return

response = requests.get(url, headers=headers, params=querystring)
data = response.json()

articles = []
if "data" in data and "main" in data["data"]:
    stream = data["data"]["main"]["stream"]
    for item in stream:
        article_content = item["content"]
        title = article_content.get("title", "No title available")
        pub_date = article_content.get("pubDate", "No date available")

        if "clickThroughUrl" in article_content and article_content["clickThroughUrl"] is not None:
            url = article_content["clickThroughUrl"]["url"]
        else:
            url = "No URL available"

        if url != "No URL available":
            processing(url)
            break

        articles.append({"Headline": title, "Date": pub_date, "URL": url})

df = pd.DataFrame(articles)
#print(df)
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Article Summary:
#  Nvidia closed the week above $138 per share, bringing its market value to $3.39 trillion . Experts say there’s growing confidence the chip giant will be the first Big Tech firm to reach a $4 trillion valuation . Nvidia CEO Jensen Huang fueled the stock's rally earlier this month after describing demand for the new chips as “insane”
